# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Extrai o dataset SPIE-AAPM Lung CT Challenge do drive. O conjunto de imagens pode ser acessado no link abaixo:
  - https://wiki.cancerimagingarchive.net/display/Public/SPIE-AAPM+Lung+CT+Challenge#19039197a19462154cc74bea92039089e61a0f44
"""

# !unzip -q /content/drive/MyDrive/TCC/dataset.zip

# %%
# !mkdir ndataset
# !mkdir ndataset/malignant
# !mkdir ndataset/benign

# %%
import os
from PIL import Image

dataset_dir = 'dataset'
ndataset_dir = 'ndataset'

for class_name in ['malignant', 'benign']:
    class_dir = os.path.join(ndataset_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

for class_name in os.listdir(dataset_dir):
    class_dir = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_dir):
        for image_file in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_file)
            if os.path.isfile(image_path):
                image = Image.open(image_path)
                new_image = image.resize((180, 180))
                save_dir = os.path.join(ndataset_dir, class_name)
                save_path = os.path.join(save_dir, image_file)
                new_image.save(save_path)

# %%
IMAGE_SIZE = (180, 180)
BATCH_SIZE = 32

train_ds, val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'ndataset',
    validation_split=0.2,
    subset='both',
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)
# Out:
# Found 19084 files belonging to 2 classes.
# Using 15268 files for training.
# Using 3816 files for validation.

# %%
data_augmentation = keras.Sequential(
    [
      layers.RandomFlip('horizontal'),
      layers.RandomRotation(0.1),
      layers.RandomContrast(0.2),
      layers.RandomZoom(0.2),
      layers.RandomTranslation(0.1, 0.1)
    ]
)

# %%
from tensorflow.keras.applications import VGG16

def make_model(input_shape):
    inputs = keras.Input(shape=input_shape)

    x = data_augmentation(inputs)

    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

    x = base_model(x)
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(1024, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation='sigmoid')(x)

    return keras.Model(inputs, outputs, name='vgg16')

model = make_model(input_shape=(180, 180, 3))
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
import keras.backend as K

def f1_score(y_true, y_pred):
    y_true = K.round(y_true)
    y_pred = K.round(y_pred)
    tp = K.sum(y_true * y_pred)
    fp = K.sum((1 - y_true) * y_pred)
    fn = K.sum(y_true * (1 - y_pred))
    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())
    return 2 * precision * recall / (precision + recall + K.epsilon())

# %%
EPOCHS = 70

callbacks = [keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5")]

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall(), f1_score]
)

# %%
history = model.fit(train_ds, epochs=EPOCHS, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/70
# 478/478 [==============================] - 47s 51ms/step - loss: 0.6579 - accuracy: 0.6001 - precision: 0.6129 - recall: 0.4788 - f1_score: 0.5197 - val_loss: 0.6291 - val_accuracy: 0.7110 - val_precision: 0.8624 - val_recall: 0.4869 - val_f1_score: 0.6107
# Epoch 2/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.4577 - accuracy: 0.7835 - precision: 0.7680 - recall: 0.7942 - f1_score: 0.7773 - val_loss: 0.2976 - val_accuracy: 0.8726 - val_precision: 0.9113 - val_recall: 0.8195 - val_f1_score: 0.8595
# Epoch 3/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.2811 - accuracy: 0.8853 - precision: 0.8792 - recall: 0.8855 - f1_score: 0.8806 - val_loss: 0.2596 - val_accuracy: 0.8839 - val_precision: 0.8176 - val_recall: 0.9818 - val_f1_score: 0.8894
# Epoch 4/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.1787 - accuracy: 0.9312 - precision: 0.9286 - recall: 0.9299 - f1_score: 0.9275 - val_loss: 0.1221 - val_accuracy: 0.9505 - val_precision: 0.9294 - val_recall: 0.9727 - val_f1_score: 0.9495
# Epoch 5/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.1230 - accuracy: 0.9521 - precision: 0.9504 - recall: 0.9509 - f1_score: 0.9488 - val_loss: 0.1258 - val_accuracy: 0.9471 - val_precision: 0.9095 - val_recall: 0.9904 - val_f1_score: 0.9469
# Epoch 6/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0866 - accuracy: 0.9678 - precision: 0.9659 - recall: 0.9679 - f1_score: 0.9655 - val_loss: 0.1398 - val_accuracy: 0.9460 - val_precision: 0.9792 - val_recall: 0.9089 - val_f1_score: 0.9402
# Epoch 7/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0771 - accuracy: 0.9728 - precision: 0.9725 - recall: 0.9714 - f1_score: 0.9708 - val_loss: 0.0660 - val_accuracy: 0.9735 - val_precision: 0.9628 - val_recall: 0.9839 - val_f1_score: 0.9724
# Epoch 8/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0629 - accuracy: 0.9780 - precision: 0.9766 - recall: 0.9781 - f1_score: 0.9764 - val_loss: 0.0876 - val_accuracy: 0.9665 - val_precision: 0.9434 - val_recall: 0.9909 - val_f1_score: 0.9660
# Epoch 9/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0536 - accuracy: 0.9822 - precision: 0.9814 - recall: 0.9819 - f1_score: 0.9809 - val_loss: 0.0811 - val_accuracy: 0.9699 - val_precision: 0.9515 - val_recall: 0.9888 - val_f1_score: 0.9692
# Epoch 10/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0487 - accuracy: 0.9821 - precision: 0.9824 - recall: 0.9806 - f1_score: 0.9812 - val_loss: 0.0430 - val_accuracy: 0.9845 - val_precision: 0.9829 - val_recall: 0.9855 - val_f1_score: 0.9842
# Epoch 11/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0404 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9849 - f1_score: 0.9841 - val_loss: 0.0875 - val_accuracy: 0.9672 - val_precision: 0.9458 - val_recall: 0.9898 - val_f1_score: 0.9664
# Epoch 12/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0395 - accuracy: 0.9862 - precision: 0.9848 - recall: 0.9868 - f1_score: 0.9829 - val_loss: 0.0804 - val_accuracy: 0.9709 - val_precision: 0.9526 - val_recall: 0.9898 - val_f1_score: 0.9707
# Epoch 13/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0402 - accuracy: 0.9860 - precision: 0.9854 - recall: 0.9858 - f1_score: 0.9849 - val_loss: 0.2100 - val_accuracy: 0.9269 - val_precision: 0.8710 - val_recall: 0.9984 - val_f1_score: 0.9291
# Epoch 14/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0299 - accuracy: 0.9892 - precision: 0.9901 - recall: 0.9876 - f1_score: 0.9885 - val_loss: 0.0355 - val_accuracy: 0.9877 - val_precision: 0.9815 - val_recall: 0.9936 - val_f1_score: 0.9871
# Epoch 15/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0343 - accuracy: 0.9874 - precision: 0.9882 - recall: 0.9858 - f1_score: 0.9867 - val_loss: 0.0467 - val_accuracy: 0.9838 - val_precision: 0.9693 - val_recall: 0.9984 - val_f1_score: 0.9834
# Epoch 16/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0259 - accuracy: 0.9917 - precision: 0.9920 - recall: 0.9910 - f1_score: 0.9915 - val_loss: 0.0874 - val_accuracy: 0.9667 - val_precision: 0.9376 - val_recall: 0.9984 - val_f1_score: 0.9666
# Epoch 17/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0186 - accuracy: 0.9935 - precision: 0.9930 - recall: 0.9935 - f1_score: 0.9930 - val_loss: 0.1051 - val_accuracy: 0.9625 - val_precision: 1.0000 - val_recall: 0.9234 - val_f1_score: 0.9582
# Epoch 18/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0313 - accuracy: 0.9887 - precision: 0.9885 - recall: 0.9883 - f1_score: 0.9879 - val_loss: 0.0443 - val_accuracy: 0.9822 - val_precision: 0.9663 - val_recall: 0.9984 - val_f1_score: 0.9821
# Epoch 19/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0328 - accuracy: 0.9883 - precision: 0.9879 - recall: 0.9881 - f1_score: 0.9867 - val_loss: 0.2757 - val_accuracy: 0.9154 - val_precision: 0.8525 - val_recall: 1.0000 - val_f1_score: 0.9182
# Epoch 20/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0218 - accuracy: 0.9932 - precision: 0.9930 - recall: 0.9930 - f1_score: 0.9927 - val_loss: 0.0451 - val_accuracy: 0.9838 - val_precision: 0.9693 - val_recall: 0.9984 - val_f1_score: 0.9835
# Epoch 21/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0269 - accuracy: 0.9912 - precision: 0.9910 - recall: 0.9908 - f1_score: 0.9902 - val_loss: 0.0569 - val_accuracy: 0.9806 - val_precision: 0.9638 - val_recall: 0.9979 - val_f1_score: 0.9800
# Epoch 22/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0162 - accuracy: 0.9952 - precision: 0.9949 - recall: 0.9953 - f1_score: 0.9946 - val_loss: 0.0816 - val_accuracy: 0.9680 - val_precision: 0.9391 - val_recall: 0.9995 - val_f1_score: 0.9668
# Epoch 23/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0317 - accuracy: 0.9892 - precision: 0.9880 - recall: 0.9897 - f1_score: 0.9883 - val_loss: 0.0648 - val_accuracy: 0.9743 - val_precision: 0.9501 - val_recall: 1.0000 - val_f1_score: 0.9739
# Epoch 24/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0165 - accuracy: 0.9940 - precision: 0.9942 - recall: 0.9934 - f1_score: 0.9935 - val_loss: 0.0110 - val_accuracy: 0.9963 - val_precision: 0.9947 - val_recall: 0.9979 - val_f1_score: 0.9964
# Epoch 25/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0200 - accuracy: 0.9936 - precision: 0.9933 - recall: 0.9935 - f1_score: 0.9932 - val_loss: 0.0591 - val_accuracy: 0.9793 - val_precision: 1.0000 - val_recall: 0.9577 - val_f1_score: 0.9777
# Epoch 26/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0176 - accuracy: 0.9939 - precision: 0.9941 - recall: 0.9934 - f1_score: 0.9935 - val_loss: 0.0115 - val_accuracy: 0.9955 - val_precision: 0.9915 - val_recall: 0.9995 - val_f1_score: 0.9954
# Epoch 27/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0136 - accuracy: 0.9957 - precision: 0.9953 - recall: 0.9958 - f1_score: 0.9952 - val_loss: 0.0897 - val_accuracy: 0.9701 - val_precision: 0.9425 - val_recall: 1.0000 - val_f1_score: 0.9699
# Epoch 28/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0206 - accuracy: 0.9927 - precision: 0.9918 - recall: 0.9931 - f1_score: 0.9919 - val_loss: 0.0167 - val_accuracy: 0.9945 - val_precision: 1.0000 - val_recall: 0.9888 - val_f1_score: 0.9945
# Epoch 29/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0182 - accuracy: 0.9938 - precision: 0.9942 - recall: 0.9931 - f1_score: 0.9935 - val_loss: 0.0219 - val_accuracy: 0.9927 - val_precision: 0.9973 - val_recall: 0.9877 - val_f1_score: 0.9921
# Epoch 30/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0132 - accuracy: 0.9949 - precision: 0.9949 - recall: 0.9946 - f1_score: 0.9940 - val_loss: 0.0214 - val_accuracy: 0.9924 - val_precision: 1.0000 - val_recall: 0.9845 - val_f1_score: 0.9921
# Epoch 31/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0272 - accuracy: 0.9908 - precision: 0.9919 - recall: 0.9892 - f1_score: 0.9902 - val_loss: 0.0447 - val_accuracy: 0.9830 - val_precision: 0.9673 - val_recall: 0.9989 - val_f1_score: 0.9824
# Epoch 32/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0164 - accuracy: 0.9942 - precision: 0.9937 - recall: 0.9943 - f1_score: 0.9930 - val_loss: 0.0262 - val_accuracy: 0.9906 - val_precision: 0.9989 - val_recall: 0.9818 - val_f1_score: 0.9899
# Epoch 33/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0213 - accuracy: 0.9927 - precision: 0.9926 - recall: 0.9924 - f1_score: 0.9919 - val_loss: 0.0291 - val_accuracy: 0.9890 - val_precision: 1.0000 - val_recall: 0.9775 - val_f1_score: 0.9875
# Epoch 34/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0129 - accuracy: 0.9960 - precision: 0.9962 - recall: 0.9955 - f1_score: 0.9956 - val_loss: 0.0091 - val_accuracy: 0.9974 - val_precision: 0.9947 - val_recall: 1.0000 - val_f1_score: 0.9973
# Epoch 35/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0132 - accuracy: 0.9958 - precision: 0.9956 - recall: 0.9958 - f1_score: 0.9951 - val_loss: 0.0134 - val_accuracy: 0.9948 - val_precision: 0.9973 - val_recall: 0.9920 - val_f1_score: 0.9949
# Epoch 36/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0124 - accuracy: 0.9957 - precision: 0.9957 - recall: 0.9955 - f1_score: 0.9933 - val_loss: 0.3165 - val_accuracy: 0.8981 - val_precision: 0.8276 - val_recall: 1.0000 - val_f1_score: 0.9050
# Epoch 37/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0343 - accuracy: 0.9897 - precision: 0.9907 - recall: 0.9881 - f1_score: 0.9895 - val_loss: 0.0106 - val_accuracy: 0.9958 - val_precision: 0.9920 - val_recall: 0.9995 - val_f1_score: 0.9955
# Epoch 38/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0079 - accuracy: 0.9974 - precision: 0.9976 - recall: 0.9970 - f1_score: 0.9972 - val_loss: 0.0363 - val_accuracy: 0.9882 - val_precision: 1.0000 - val_recall: 0.9759 - val_f1_score: 0.9877
# Epoch 39/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0115 - accuracy: 0.9959 - precision: 0.9961 - recall: 0.9955 - f1_score: 0.9956 - val_loss: 0.0069 - val_accuracy: 0.9976 - val_precision: 0.9957 - val_recall: 0.9995 - val_f1_score: 0.9975
# Epoch 40/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0128 - accuracy: 0.9957 - precision: 0.9953 - recall: 0.9958 - f1_score: 0.9951 - val_loss: 0.0117 - val_accuracy: 0.9971 - val_precision: 0.9941 - val_recall: 1.0000 - val_f1_score: 0.9970
# Epoch 41/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0084 - accuracy: 0.9976 - precision: 0.9980 - recall: 0.9972 - f1_score: 0.9977 - val_loss: 0.0279 - val_accuracy: 0.9911 - val_precision: 0.9821 - val_recall: 1.0000 - val_f1_score: 0.9911
# Epoch 42/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0114 - accuracy: 0.9963 - precision: 0.9961 - recall: 0.9962 - f1_score: 0.9961 - val_loss: 0.0141 - val_accuracy: 0.9948 - val_precision: 0.9910 - val_recall: 0.9984 - val_f1_score: 0.9945
# Epoch 43/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0119 - accuracy: 0.9961 - precision: 0.9956 - recall: 0.9965 - f1_score: 0.9957 - val_loss: 0.0205 - val_accuracy: 0.9921 - val_precision: 0.9862 - val_recall: 0.9979 - val_f1_score: 0.9919
# Epoch 44/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0101 - accuracy: 0.9961 - precision: 0.9961 - recall: 0.9960 - f1_score: 0.9958 - val_loss: 0.0961 - val_accuracy: 0.9641 - val_precision: 0.9321 - val_recall: 0.9995 - val_f1_score: 0.9636
# Epoch 45/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0117 - accuracy: 0.9965 - precision: 0.9970 - recall: 0.9957 - f1_score: 0.9964 - val_loss: 0.0025 - val_accuracy: 0.9995 - val_precision: 0.9995 - val_recall: 0.9995 - val_f1_score: 0.9995
# Epoch 46/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0087 - accuracy: 0.9975 - precision: 0.9974 - recall: 0.9974 - f1_score: 0.9971 - val_loss: 0.0029 - val_accuracy: 0.9992 - val_precision: 1.0000 - val_recall: 0.9984 - val_f1_score: 0.9992
# Epoch 47/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0175 - accuracy: 0.9946 - precision: 0.9939 - recall: 0.9950 - f1_score: 0.9937 - val_loss: 0.0083 - val_accuracy: 0.9969 - val_precision: 0.9973 - val_recall: 0.9963 - val_f1_score: 0.9966
# Epoch 48/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0101 - accuracy: 0.9964 - precision: 0.9964 - recall: 0.9962 - f1_score: 0.9941 - val_loss: 0.0074 - val_accuracy: 0.9974 - val_precision: 0.9947 - val_recall: 1.0000 - val_f1_score: 0.9974
# Epoch 49/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0116 - accuracy: 0.9961 - precision: 0.9958 - recall: 0.9962 - f1_score: 0.9956 - val_loss: 0.0048 - val_accuracy: 0.9982 - val_precision: 0.9984 - val_recall: 0.9979 - val_f1_score: 0.9980
# Epoch 50/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0068 - accuracy: 0.9972 - precision: 0.9973 - recall: 0.9970 - f1_score: 0.9970 - val_loss: 0.0042 - val_accuracy: 0.9987 - val_precision: 0.9979 - val_recall: 0.9995 - val_f1_score: 0.9987
# Epoch 51/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0072 - accuracy: 0.9975 - precision: 0.9974 - recall: 0.9974 - f1_score: 0.9973 - val_loss: 0.0105 - val_accuracy: 0.9950 - val_precision: 0.9995 - val_recall: 0.9904 - val_f1_score: 0.9950
# Epoch 52/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0076 - accuracy: 0.9976 - precision: 0.9974 - recall: 0.9976 - f1_score: 0.9973 - val_loss: 0.0807 - val_accuracy: 0.9743 - val_precision: 0.9510 - val_recall: 0.9989 - val_f1_score: 0.9738
# Epoch 53/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0106 - accuracy: 0.9963 - precision: 0.9964 - recall: 0.9961 - f1_score: 0.9962 - val_loss: 0.0069 - val_accuracy: 0.9976 - val_precision: 0.9952 - val_recall: 1.0000 - val_f1_score: 0.9973
# Epoch 54/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0101 - accuracy: 0.9959 - precision: 0.9954 - recall: 0.9962 - f1_score: 0.9955 - val_loss: 0.0254 - val_accuracy: 0.9890 - val_precision: 0.9795 - val_recall: 0.9984 - val_f1_score: 0.9888
# Epoch 55/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0063 - accuracy: 0.9976 - precision: 0.9977 - recall: 0.9974 - f1_score: 0.9975 - val_loss: 0.1027 - val_accuracy: 0.9641 - val_precision: 1.0000 - val_recall: 0.9266 - val_f1_score: 0.9599
# Epoch 56/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0079 - accuracy: 0.9975 - precision: 0.9974 - recall: 0.9974 - f1_score: 0.9973 - val_loss: 0.0036 - val_accuracy: 0.9990 - val_precision: 0.9995 - val_recall: 0.9984 - val_f1_score: 0.9990
# Epoch 57/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0095 - accuracy: 0.9966 - precision: 0.9964 - recall: 0.9966 - f1_score: 0.9964 - val_loss: 0.0163 - val_accuracy: 0.9937 - val_precision: 0.9873 - val_recall: 1.0000 - val_f1_score: 0.9933
# Epoch 58/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0054 - accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - f1_score: 0.9979 - val_loss: 0.0742 - val_accuracy: 0.9743 - val_precision: 0.9501 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 59/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0102 - accuracy: 0.9969 - precision: 0.9966 - recall: 0.9969 - f1_score: 0.9965 - val_loss: 0.0113 - val_accuracy: 0.9966 - val_precision: 1.0000 - val_recall: 0.9930 - val_f1_score: 0.9964
# Epoch 60/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0055 - accuracy: 0.9982 - precision: 0.9982 - recall: 0.9981 - f1_score: 0.9979 - val_loss: 0.0096 - val_accuracy: 0.9971 - val_precision: 0.9952 - val_recall: 0.9989 - val_f1_score: 0.9971
# Epoch 61/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0109 - accuracy: 0.9965 - precision: 0.9962 - recall: 0.9965 - f1_score: 0.9958 - val_loss: 0.0089 - val_accuracy: 0.9966 - val_precision: 0.9941 - val_recall: 0.9989 - val_f1_score: 0.9965
# Epoch 62/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0066 - accuracy: 0.9975 - precision: 0.9973 - recall: 0.9976 - f1_score: 0.9972 - val_loss: 0.0294 - val_accuracy: 0.9898 - val_precision: 1.0000 - val_recall: 0.9791 - val_f1_score: 0.9893
# Epoch 63/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0077 - accuracy: 0.9977 - precision: 0.9976 - recall: 0.9977 - f1_score: 0.9975 - val_loss: 0.0387 - val_accuracy: 0.9874 - val_precision: 1.0000 - val_recall: 0.9743 - val_f1_score: 0.9868
# Epoch 64/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0040 - accuracy: 0.9986 - precision: 0.9987 - recall: 0.9985 - f1_score: 0.9984 - val_loss: 0.0396 - val_accuracy: 0.9885 - val_precision: 1.0000 - val_recall: 0.9764 - val_f1_score: 0.9883
# Epoch 65/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0099 - accuracy: 0.9975 - precision: 0.9974 - recall: 0.9974 - f1_score: 0.9970 - val_loss: 0.0397 - val_accuracy: 0.9861 - val_precision: 0.9994 - val_recall: 0.9721 - val_f1_score: 0.9849
# Epoch 66/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0113 - accuracy: 0.9964 - precision: 0.9962 - recall: 0.9964 - f1_score: 0.9962 - val_loss: 0.0057 - val_accuracy: 0.9979 - val_precision: 0.9957 - val_recall: 1.0000 - val_f1_score: 0.9979
# Epoch 67/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0048 - accuracy: 0.9982 - precision: 0.9978 - recall: 0.9985 - f1_score: 0.9979 - val_loss: 0.0067 - val_accuracy: 0.9974 - val_precision: 1.0000 - val_recall: 0.9946 - val_f1_score: 0.9974
# Epoch 68/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0043 - accuracy: 0.9986 - precision: 0.9985 - recall: 0.9987 - f1_score: 0.9984 - val_loss: 0.0138 - val_accuracy: 0.9945 - val_precision: 0.9904 - val_recall: 0.9984 - val_f1_score: 0.9942
# Epoch 69/70
# 478/478 [==============================] - 23s 47ms/step - loss: 0.0047 - accuracy: 0.9984 - precision: 0.9981 - recall: 0.9985 - f1_score: 0.9982 - val_loss: 0.0071 - val_accuracy: 0.9971 - val_precision: 0.9941 - val_recall: 1.0000 - val_f1_score: 0.9967
# Epoch 70/70
# 478/478 [==============================] - 23s 48ms/step - loss: 0.0077 - accuracy: 0.9971 - precision: 0.9972 - recall: 0.9968 - f1_score: 0.9968 - val_loss: 0.1165 - val_accuracy: 0.9615 - val_precision: 0.9270 - val_recall: 1.0000 - val_f1_score: 0.9620

# %%
import matplotlib.pyplot as plt

test_loss, test_acc, test_precision, test_recall, test_f1_score = model.evaluate(val_ds)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)
print('Test F1Score:', test_f1_score)

fig, axs = plt.subplots(5, figsize=(8, 12))

# Loss plot
axs[0].plot(history.history['loss'], label='train')
axs[0].plot(history.history['val_loss'], label='val')
axs[0].set_title('Model Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Accuracy plot
axs[1].plot(history.history['accuracy'], label='train')
axs[1].plot(history.history['val_accuracy'], label='val')
axs[1].set_title('Model Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Precision plot
axs[2].plot(history.history['precision'], label='train')
axs[2].plot(history.history['val_precision'], label='val')
axs[2].set_title('Model Precision')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Precision')
axs[2].legend()

# Recall plot
axs[3].plot(history.history['recall'], label='train')
axs[3].plot(history.history['val_recall'], label='val')
axs[3].set_title('Model Recall')
axs[3].set_xlabel('Epoch')
axs[3].set_ylabel('Recall')
axs[3].legend()

# F1Score plot
axs[4].plot(history.history['f1_score'], label='train')
axs[4].plot(history.history['val_f1_score'], label='val')
axs[4].set_title('Model F1Score')
axs[4].set_xlabel('Epoch')
axs[4].set_ylabel('F1Score')
axs[4].legend()

plt.tight_layout()
plt.show()
# Out:
# 120/120 [==============================] - 2s 17ms/step - loss: 0.1165 - accuracy: 0.9615 - precision: 0.9270 - recall: 1.0000 - f1_score: 0.9620
# Test Loss: 0.11648402363061905
# Test Accuracy: 0.9614779949188232
# Test Precision: 0.9270108938217163
# Test Recall: 1.0
# Test F1Score: 0.9619611501693726

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

threshold = 0.999 # Limiar de decisão

y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = model.predict(val_ds)

y_true_binary = y_true.astype(int)
y_pred_binary = (y_pred > threshold).astype(int)

conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
class_report = classification_report(y_true_binary, y_pred_binary)

print('Confusion Matrix:', conf_matrix)
print('Classification Report:', class_report)
# Out:
# 120/120 [==============================] - 2s 15ms/step
# Confusion Matrix: [[1941    8]
#  [  33 1834]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1949
#            1       1.00      0.98      0.99      1867
#
#     accuracy                           0.99      3816
#    macro avg       0.99      0.99      0.99      3816
# weighted avg       0.99      0.99      0.99      3816
