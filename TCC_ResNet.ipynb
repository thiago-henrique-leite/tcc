# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/TCC/dataset.zip

# %%
# !ls dataset
# Out:
# benign	malignant

# %%
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "dataset",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "dataset",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)

train_ds.class_names
# Out:
# Found 19084 files belonging to 2 classes.
# Using 15268 files for training.
# Found 19084 files belonging to 2 classes.
# Using 3816 files for validation.
# ['benign', 'malignant']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
input_shape = (50,50,3)
inputs = keras.Input(shape=input_shape)
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
...  # Rest of the model
# Out:
# Ellipsis

# %%
augmented_train_ds = train_ds.map(
  lambda x, y: (data_augmentation(x, training=True), y))

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
from keras.applications import ResNet50

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    x = base_model(x)

    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs, name='resnet50')

model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
epochs = 50

callbacks = [keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5")]

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

model.fit(train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/50
# 478/478 [==============================] - 185s 275ms/step - loss: 0.6158 - accuracy: 0.6486 - val_loss: 0.6249 - val_accuracy: 0.6177
# Epoch 2/50
# 478/478 [==============================] - 130s 271ms/step - loss: 0.4467 - accuracy: 0.7809 - val_loss: 1.5283 - val_accuracy: 0.6468
# Epoch 3/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.3253 - accuracy: 0.8596 - val_loss: 0.7281 - val_accuracy: 0.7353
# Epoch 4/50
# 478/478 [==============================] - 131s 274ms/step - loss: 0.2345 - accuracy: 0.9035 - val_loss: 0.5513 - val_accuracy: 0.7738
# Epoch 5/50
# 478/478 [==============================] - 132s 274ms/step - loss: 0.1646 - accuracy: 0.9364 - val_loss: 0.9734 - val_accuracy: 0.7372
# Epoch 6/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.1378 - accuracy: 0.9473 - val_loss: 0.3544 - val_accuracy: 0.8776
# Epoch 7/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0925 - accuracy: 0.9648 - val_loss: 0.1979 - val_accuracy: 0.9316
# Epoch 8/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0814 - accuracy: 0.9710 - val_loss: 0.5351 - val_accuracy: 0.8451
# Epoch 9/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0926 - accuracy: 0.9661 - val_loss: 0.6763 - val_accuracy: 0.8284
# Epoch 10/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0593 - accuracy: 0.9788 - val_loss: 0.6705 - val_accuracy: 0.8443
# Epoch 11/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0485 - accuracy: 0.9843 - val_loss: 0.2489 - val_accuracy: 0.9279
# Epoch 12/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0466 - accuracy: 0.9839 - val_loss: 0.2368 - val_accuracy: 0.9374
# Epoch 13/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0502 - accuracy: 0.9820 - val_loss: 0.6915 - val_accuracy: 0.8564
# Epoch 14/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0369 - accuracy: 0.9862 - val_loss: 0.1500 - val_accuracy: 0.9515
# Epoch 15/50
# 478/478 [==============================] - 131s 272ms/step - loss: 0.0364 - accuracy: 0.9879 - val_loss: 0.2229 - val_accuracy: 0.9269
# Epoch 16/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.0611 - val_accuracy: 0.9796
# Epoch 17/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0339 - accuracy: 0.9884 - val_loss: 0.0833 - val_accuracy: 0.9709
# Epoch 18/50
# 478/478 [==============================] - 130s 271ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.3616 - val_accuracy: 0.9080
# Epoch 19/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0244 - accuracy: 0.9925 - val_loss: 3.2398 - val_accuracy: 0.6771
# Epoch 20/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.2950 - val_accuracy: 0.9253
# Epoch 21/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0487 - accuracy: 0.9834 - val_loss: 0.0744 - val_accuracy: 0.9790
# Epoch 22/50
# 478/478 [==============================] - 130s 271ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.3927 - val_accuracy: 0.8968
# Epoch 23/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0736 - val_accuracy: 0.9785
# Epoch 24/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.1771 - val_accuracy: 0.9515
# Epoch 25/50
# 478/478 [==============================] - 130s 271ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0288 - val_accuracy: 0.9879
# Epoch 26/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.7138 - val_accuracy: 0.8556
# Epoch 27/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 0.4246 - val_accuracy: 0.8954
# Epoch 28/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.1110 - val_accuracy: 0.9675
# Epoch 29/50
# 478/478 [==============================] - 130s 271ms/step - loss: 0.0267 - accuracy: 0.9916 - val_loss: 0.0329 - val_accuracy: 0.9877
# Epoch 30/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0146 - val_accuracy: 0.9940
# Epoch 31/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 0.2604 - val_accuracy: 0.9387
# Epoch 32/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.2342 - val_accuracy: 0.9264
# Epoch 33/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.1642 - val_accuracy: 0.9518
# Epoch 34/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0639 - val_accuracy: 0.9775
# Epoch 35/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.0190 - val_accuracy: 0.9929
# Epoch 36/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0591 - val_accuracy: 0.9785
# Epoch 37/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.5238 - val_accuracy: 0.8968
# Epoch 38/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.2075 - val_accuracy: 0.9536
# Epoch 39/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.1105 - val_accuracy: 0.9646
# Epoch 40/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0147 - accuracy: 0.9963 - val_loss: 0.0421 - val_accuracy: 0.9877
# Epoch 41/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.5880 - val_accuracy: 0.8574
# Epoch 42/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.2770 - val_accuracy: 0.9337
# Epoch 43/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0432 - val_accuracy: 0.9866
# Epoch 44/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0785 - val_accuracy: 0.9788
# Epoch 45/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.2362 - val_accuracy: 0.9442
# Epoch 46/50
# 478/478 [==============================] - 133s 277ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 1.0731 - val_accuracy: 0.8205
# Epoch 47/50
# 478/478 [==============================] - 131s 273ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.2305 - val_accuracy: 0.9400
# Epoch 48/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.1405 - val_accuracy: 0.9691
# Epoch 49/50
# 478/478 [==============================] - 132s 276ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0180 - val_accuracy: 0.9929
# Epoch 50/50
# 478/478 [==============================] - 130s 272ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 2.5121 - val_accuracy: 0.6965

# %%
def classify_image(image_path):
  img = keras.preprocessing.image.load_img(image_path, target_size=image_size)
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)
  predictions = model.predict(img_array)
  score = predictions[0]
  benign = 100 * (1 - score)
  malignant = 100 * score
  print("This image is %.2f%% benign and %.2f%% malignant." % (benign, malignant))

# %%
image_path = "dataset/benign/011-001.jpg"

classify_image(image_path)
# Out:
# 1/1 [==============================] - 2s 2s/step
# This image is 100.00% benign and 0.00% malignant.

# %%
image_path = "dataset/malignant/011-006.jpg"

classify_image(image_path)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# This image is 0.00% benign and 100.00% malignant.
