# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Extrai o dataset SPIE-AAPM Lung CT Challenge do drive. O conjunto de imagens pode ser acessado no link abaixo:
  - https://wiki.cancerimagingarchive.net/display/Public/SPIE-AAPM+Lung+CT+Challenge#19039197a19462154cc74bea92039089e61a0f44
"""

# !unzip -q /content/drive/MyDrive/TCC/dataset.zip

# %%
"""
O código abaixo realiza as seguintes operações:
  - Redimensiona as imagens para um tamanho especificado;
  - Define um tamanho de lote para o treinamento do modelo;
  - Divide as imagens em conjuntos de treinamento e validação;
  - Imprime o nome das classes do dataset.
"""

IMAGE_SIZE = (180,180)
BATCH_SIZE = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'dataset',
    validation_split=0.2,
    subset='training',
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'dataset',
    validation_split=0.2,
    subset='validation',
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)

train_ds.class_names
# Out:
# Found 19084 files belonging to 2 classes.
# Using 15268 files for training.
# Found 19084 files belonging to 2 classes.
# Using 3816 files for validation.
# ['benign', 'malignant']

# %%
"""
Esse código cria uma figura com nove subplots e plota nove imagens aleatórias do conjunto
de treinamento do modelo - que contém tumores benignos (0) e malignos (1).
"""

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(int(labels[i]))
        plt.axis('off')

# %%
"""
Realiza o processo de data augmentation nas imagens:
  - Aplica uma operação de espelhamento horizontal aleatório nas imagens de entrada;
  - Aplica uma rotação nas imagens de entrada com uma amplitude de até 0.1 radianos.
"""

from tensorflow.keras import layers

data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
])

# %%
"""
Exibe 10 imagens do dataset após o processo de data augmentation.
"""

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
"""
Permite que o conjunto de dados carregue 32 lotes de dados em segundo plano enquanto
o modelo está sendo treinado com o lote anterior.
"""

BUFFER_SIZE=32

train_ds = train_ds.prefetch(buffer_size=BUFFER_SIZE)
val_ds = val_ds.prefetch(buffer_size=BUFFER_SIZE)

# %%
"""
Constrói o modelo baseado na arquitetura Xception
"""

from keras.applications.xception import Xception

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    x = data_augmentation(inputs)

    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)

    x = base_model(x)
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(units=1, activation='sigmoid')(x)

    return keras.Model(inputs, outputs, name='xception')

model = make_model(input_shape=IMAGE_SIZE + (3,), num_classes=2)

keras.utils.plot_model(model, show_shapes=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step

# %%
"""
Executa o treinamento do modelo Xception
"""

EPOCHS=50

callbacks = [keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5")]

model.compile(optimizer=keras.optimizers.Adam(1e-3), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(train_ds, epochs=EPOCHS, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/50
# 478/478 [==============================] - 211s 334ms/step - loss: 0.3956 - accuracy: 0.8080 - val_loss: 0.4890 - val_accuracy: 0.8467
# Epoch 2/50
# 478/478 [==============================] - 167s 349ms/step - loss: 0.1551 - accuracy: 0.9382 - val_loss: 0.7581 - val_accuracy: 0.8336
# Epoch 3/50
# 478/478 [==============================] - 167s 347ms/step - loss: 0.0964 - accuracy: 0.9650 - val_loss: 0.5654 - val_accuracy: 0.8721
# Epoch 4/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0661 - accuracy: 0.9758 - val_loss: 0.0407 - val_accuracy: 0.9817
# Epoch 5/50
# 478/478 [==============================] - 167s 349ms/step - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.2151 - val_accuracy: 0.9308
# Epoch 6/50
# 478/478 [==============================] - 166s 348ms/step - loss: 0.0509 - accuracy: 0.9832 - val_loss: 0.0403 - val_accuracy: 0.9832
# Epoch 7/50
# 478/478 [==============================] - 167s 349ms/step - loss: 0.0291 - accuracy: 0.9903 - val_loss: 0.0775 - val_accuracy: 0.9727
# Epoch 8/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0319 - accuracy: 0.9891 - val_loss: 0.1206 - val_accuracy: 0.9583
# Epoch 9/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0231 - accuracy: 0.9915 - val_loss: 0.5914 - val_accuracy: 0.8532
# Epoch 10/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 0.5206 - val_accuracy: 0.8593
# Epoch 11/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0451 - accuracy: 0.9838 - val_loss: 0.0480 - val_accuracy: 0.9843
# Epoch 12/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0311 - accuracy: 0.9897 - val_loss: 0.1190 - val_accuracy: 0.9555
# Epoch 13/50
# 478/478 [==============================] - 167s 349ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.1961 - val_accuracy: 0.9408
# Epoch 14/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.0127 - val_accuracy: 0.9948
# Epoch 15/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.0597 - val_accuracy: 0.9809
# Epoch 16/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0092 - val_accuracy: 0.9958
# Epoch 17/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.8806 - val_accuracy: 0.7896
# Epoch 18/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.1901 - val_accuracy: 0.9573
# Epoch 19/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0491 - val_accuracy: 0.9848
# Epoch 20/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0521 - val_accuracy: 0.9848
# Epoch 21/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0371 - accuracy: 0.9876 - val_loss: 0.0295 - val_accuracy: 0.9937
# Epoch 22/50
# 478/478 [==============================] - 166s 348ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.1575 - val_accuracy: 0.9610
# Epoch 23/50
# 478/478 [==============================] - 166s 348ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0493 - val_accuracy: 0.9801
# Epoch 24/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.1827 - val_accuracy: 0.9444
# Epoch 25/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.5728 - val_accuracy: 0.8719
# Epoch 26/50
# 478/478 [==============================] - 166s 348ms/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.2413 - val_accuracy: 0.9222
# Epoch 27/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0247 - val_accuracy: 0.9919
# Epoch 28/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0125 - val_accuracy: 0.9963
# Epoch 29/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.0438 - val_accuracy: 0.9848
# Epoch 30/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0641 - val_accuracy: 0.9796
# Epoch 31/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.0948 - val_accuracy: 0.9686
# Epoch 32/50
# 478/478 [==============================] - 167s 349ms/step - loss: 0.0074 - accuracy: 0.9972 - val_loss: 0.1659 - val_accuracy: 0.9586
# Epoch 33/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0084 - accuracy: 0.9976 - val_loss: 0.0117 - val_accuracy: 0.9958
# Epoch 34/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0244 - val_accuracy: 0.9919
# Epoch 35/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0227 - val_accuracy: 0.9916
# Epoch 36/50
# 478/478 [==============================] - 167s 348ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0077 - val_accuracy: 0.9963
# Epoch 37/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.0685 - val_accuracy: 0.9790
# Epoch 38/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0104 - val_accuracy: 0.9969
# Epoch 39/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0130 - val_accuracy: 0.9940
# Epoch 40/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.1303 - val_accuracy: 0.9591
# Epoch 41/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0295 - val_accuracy: 0.9898
# Epoch 42/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0438 - val_accuracy: 0.9843
# Epoch 43/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0049 - val_accuracy: 0.9984
# Epoch 44/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0298 - val_accuracy: 0.9916
# Epoch 45/50
# 478/478 [==============================] - 166s 346ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0051 - val_accuracy: 0.9987
# Epoch 46/50
# 478/478 [==============================] - 166s 346ms/step - loss: 9.6930e-04 - accuracy: 0.9997 - val_loss: 0.0065 - val_accuracy: 0.9979
# Epoch 47/50
# 478/478 [==============================] - 166s 347ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0212 - val_accuracy: 0.9908
# Epoch 48/50
# 478/478 [==============================] - 166s 345ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0158 - val_accuracy: 0.9945
# Epoch 49/50
# 478/478 [==============================] - 166s 346ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0316 - val_accuracy: 0.9893
# Epoch 50/50
# 478/478 [==============================] - 166s 346ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0021 - val_accuracy: 0.9995

# %%
"""
Método que utiliza o modelo treinado para classificar uma imagem
"""

def classify_image(image_path):
  img = keras.preprocessing.image.load_img(image_path, target_size=IMAGE_SIZE)
  img_array = keras.preprocessing.image.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0)
  predictions = model.predict(img_array)
  score = predictions[0]
  benign = 100 * (1 - score)
  malignant = 100 * score

  print("This image is %.2f%% benign and %.2f%% malignant." % (benign, malignant))

# %%
"""
Testa o modelo classificando uma imagem com tumor benigno
"""

classify_image('dataset/benign/011-001.jpg')
# Out:
# 1/1 [==============================] - 2s 2s/step
# This image is 90.46% benign and 9.54% malignant.

# %%
"""
Testa o modelo classificando uma imagem com tumor maligno
"""

classify_image('dataset/malignant/011-006.jpg')
# Out:
# 1/1 [==============================] - 0s 31ms/step
# This image is 0.02% benign and 99.98% malignant.
