# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Extrai o dataset SPIE-AAPM Lung CT Challenge do drive. O conjunto de imagens pode ser acessado no link abaixo:
  - https://wiki.cancerimagingarchive.net/display/Public/SPIE-AAPM+Lung+CT+Challenge#19039197a19462154cc74bea92039089e61a0f44
"""

# !unzip -q /content/drive/MyDrive/TCC/dataset.zip

# %%
# !mkdir ndataset
# !mkdir ndataset/malignant
# !mkdir ndataset/benign

# %%
import os
from PIL import Image

dataset_dir = 'dataset'
ndataset_dir = 'ndataset'

for class_name in ['malignant', 'benign']:
    class_dir = os.path.join(ndataset_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

for class_name in os.listdir(dataset_dir):
    class_dir = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_dir):
        for image_file in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_file)
            if os.path.isfile(image_path):
                image = Image.open(image_path)
                new_image = image.resize((180, 180))
                save_dir = os.path.join(ndataset_dir, class_name)
                save_path = os.path.join(save_dir, image_file)
                new_image.save(save_path)

# %%
IMAGE_SIZE = (180, 180)
BATCH_SIZE = 32

train_ds, val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'ndataset',
    validation_split=0.2,
    subset='both',
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
)
# Out:
# Found 19084 files belonging to 2 classes.
# Using 15268 files for training.
# Using 3816 files for validation.

# %%
data_augmentation = keras.Sequential(
    [
      layers.RandomFlip('horizontal'),
      layers.RandomRotation(0.1),
      layers.RandomContrast(0.2),
      layers.RandomZoom(0.2),
      layers.RandomTranslation(0.1, 0.1)
    ]
)

# %%
from keras.applications.xception import Xception

def make_model(input_shape):
    inputs = keras.Input(shape=input_shape)

    x = data_augmentation(inputs)

    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)

    x = base_model(x)
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(1024, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation='sigmoid')(x)

    return keras.Model(inputs, outputs, name='vgg16')

model = make_model(input_shape=(180, 180, 3))
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step

# %%
import keras.backend as K

def f1_score(y_true, y_pred):
    y_true = K.round(y_true)
    y_pred = K.round(y_pred)
    tp = K.sum(y_true * y_pred)
    fp = K.sum((1 - y_true) * y_pred)
    fn = K.sum(y_true * (1 - y_pred))
    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())
    return 2 * precision * recall / (precision + recall + K.epsilon())

# %%
EPOCHS = 70

callbacks = [keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5")]

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall(), f1_score]
)

# %%
history = model.fit(train_ds, epochs=EPOCHS, callbacks=callbacks, validation_data=val_ds)
# Out:
# Epoch 1/70
# 478/478 [==============================] - 75s 67ms/step - loss: 0.6685 - accuracy: 0.5855 - precision: 0.5612 - recall: 0.6706 - f1_score: 0.6060 - val_loss: 0.6830 - val_accuracy: 0.5270 - val_precision: 0.9844 - val_recall: 0.0337 - val_f1_score: 0.0605
# Epoch 2/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.5058 - accuracy: 0.7472 - precision: 0.7339 - recall: 0.7522 - f1_score: 0.7395 - val_loss: 0.4100 - val_accuracy: 0.8040 - val_precision: 0.8127 - val_recall: 0.7788 - val_f1_score: 0.7915
# Epoch 3/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.3595 - accuracy: 0.8393 - precision: 0.8342 - recall: 0.8352 - f1_score: 0.8325 - val_loss: 0.2997 - val_accuracy: 0.8692 - val_precision: 0.8615 - val_recall: 0.8731 - val_f1_score: 0.8645
# Epoch 4/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.2649 - accuracy: 0.8892 - precision: 0.8848 - recall: 0.8875 - f1_score: 0.8835 - val_loss: 0.2324 - val_accuracy: 0.9057 - val_precision: 0.9006 - val_recall: 0.9073 - val_f1_score: 0.9011
# Epoch 5/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.1923 - accuracy: 0.9230 - precision: 0.9187 - recall: 0.9231 - f1_score: 0.9191 - val_loss: 0.1995 - val_accuracy: 0.9154 - val_precision: 0.8967 - val_recall: 0.9347 - val_f1_score: 0.9140
# Epoch 6/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.1519 - accuracy: 0.9400 - precision: 0.9373 - recall: 0.9393 - f1_score: 0.9365 - val_loss: 0.1625 - val_accuracy: 0.9371 - val_precision: 0.9458 - val_recall: 0.9245 - val_f1_score: 0.9334
# Epoch 7/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.1232 - accuracy: 0.9519 - precision: 0.9489 - recall: 0.9523 - f1_score: 0.9490 - val_loss: 0.1415 - val_accuracy: 0.9452 - val_precision: 0.9230 - val_recall: 0.9689 - val_f1_score: 0.9448
# Epoch 8/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0994 - accuracy: 0.9633 - precision: 0.9616 - recall: 0.9628 - f1_score: 0.9612 - val_loss: 0.1205 - val_accuracy: 0.9541 - val_precision: 0.9277 - val_recall: 0.9829 - val_f1_score: 0.9526
# Epoch 9/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0849 - accuracy: 0.9691 - precision: 0.9669 - recall: 0.9695 - f1_score: 0.9666 - val_loss: 0.1181 - val_accuracy: 0.9557 - val_precision: 0.9332 - val_recall: 0.9796 - val_f1_score: 0.9546
# Epoch 10/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0793 - accuracy: 0.9709 - precision: 0.9677 - recall: 0.9725 - f1_score: 0.9689 - val_loss: 0.0919 - val_accuracy: 0.9649 - val_precision: 0.9544 - val_recall: 0.9748 - val_f1_score: 0.9640
# Epoch 11/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0685 - accuracy: 0.9743 - precision: 0.9756 - recall: 0.9713 - f1_score: 0.9726 - val_loss: 0.0704 - val_accuracy: 0.9733 - val_precision: 0.9580 - val_recall: 0.9888 - val_f1_score: 0.9726
# Epoch 12/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0609 - accuracy: 0.9788 - precision: 0.9784 - recall: 0.9780 - f1_score: 0.9753 - val_loss: 0.0587 - val_accuracy: 0.9782 - val_precision: 0.9720 - val_recall: 0.9839 - val_f1_score: 0.9776
# Epoch 13/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0546 - accuracy: 0.9802 - precision: 0.9800 - recall: 0.9791 - f1_score: 0.9790 - val_loss: 0.0538 - val_accuracy: 0.9796 - val_precision: 0.9691 - val_recall: 0.9898 - val_f1_score: 0.9790
# Epoch 14/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0470 - accuracy: 0.9831 - precision: 0.9826 - recall: 0.9826 - f1_score: 0.9811 - val_loss: 0.0496 - val_accuracy: 0.9811 - val_precision: 0.9726 - val_recall: 0.9893 - val_f1_score: 0.9805
# Epoch 15/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0442 - accuracy: 0.9841 - precision: 0.9835 - recall: 0.9837 - f1_score: 0.9828 - val_loss: 0.0583 - val_accuracy: 0.9767 - val_precision: 0.9582 - val_recall: 0.9957 - val_f1_score: 0.9765
# Epoch 16/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0392 - accuracy: 0.9870 - precision: 0.9872 - recall: 0.9860 - f1_score: 0.9861 - val_loss: 0.0636 - val_accuracy: 0.9756 - val_precision: 0.9563 - val_recall: 0.9957 - val_f1_score: 0.9755
# Epoch 17/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0336 - accuracy: 0.9887 - precision: 0.9889 - recall: 0.9877 - f1_score: 0.9876 - val_loss: 0.0324 - val_accuracy: 0.9879 - val_precision: 0.9820 - val_recall: 0.9936 - val_f1_score: 0.9876
# Epoch 18/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0369 - accuracy: 0.9868 - precision: 0.9868 - recall: 0.9860 - f1_score: 0.9856 - val_loss: 0.0485 - val_accuracy: 0.9801 - val_precision: 0.9642 - val_recall: 0.9963 - val_f1_score: 0.9794
# Epoch 19/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0318 - accuracy: 0.9890 - precision: 0.9880 - recall: 0.9893 - f1_score: 0.9874 - val_loss: 0.0280 - val_accuracy: 0.9895 - val_precision: 0.9841 - val_recall: 0.9946 - val_f1_score: 0.9889
# Epoch 20/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0300 - accuracy: 0.9897 - precision: 0.9889 - recall: 0.9897 - f1_score: 0.9888 - val_loss: 0.0431 - val_accuracy: 0.9864 - val_precision: 0.9764 - val_recall: 0.9963 - val_f1_score: 0.9856
# Epoch 21/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0237 - accuracy: 0.9921 - precision: 0.9922 - recall: 0.9916 - f1_score: 0.9913 - val_loss: 0.0257 - val_accuracy: 0.9908 - val_precision: 0.9904 - val_recall: 0.9909 - val_f1_score: 0.9899
# Epoch 22/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0266 - accuracy: 0.9909 - precision: 0.9910 - recall: 0.9903 - f1_score: 0.9898 - val_loss: 0.0359 - val_accuracy: 0.9879 - val_precision: 0.9775 - val_recall: 0.9984 - val_f1_score: 0.9874
# Epoch 23/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0261 - accuracy: 0.9913 - precision: 0.9914 - recall: 0.9907 - f1_score: 0.9903 - val_loss: 0.0272 - val_accuracy: 0.9898 - val_precision: 0.9872 - val_recall: 0.9920 - val_f1_score: 0.9894
# Epoch 24/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0222 - accuracy: 0.9926 - precision: 0.9924 - recall: 0.9923 - f1_score: 0.9914 - val_loss: 0.0185 - val_accuracy: 0.9940 - val_precision: 0.9915 - val_recall: 0.9963 - val_f1_score: 0.9937
# Epoch 25/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0197 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9929 - f1_score: 0.9927 - val_loss: 0.0178 - val_accuracy: 0.9942 - val_precision: 0.9899 - val_recall: 0.9984 - val_f1_score: 0.9938
# Epoch 26/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0187 - accuracy: 0.9938 - precision: 0.9935 - recall: 0.9938 - f1_score: 0.9931 - val_loss: 0.0149 - val_accuracy: 0.9948 - val_precision: 0.9915 - val_recall: 0.9979 - val_f1_score: 0.9943
# Epoch 27/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0184 - accuracy: 0.9940 - precision: 0.9934 - recall: 0.9943 - f1_score: 0.9932 - val_loss: 0.0205 - val_accuracy: 0.9929 - val_precision: 0.9878 - val_recall: 0.9979 - val_f1_score: 0.9924
# Epoch 28/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0162 - accuracy: 0.9950 - precision: 0.9950 - recall: 0.9947 - f1_score: 0.9940 - val_loss: 0.0092 - val_accuracy: 0.9974 - val_precision: 0.9952 - val_recall: 0.9995 - val_f1_score: 0.9971
# Epoch 29/70
# 478/478 [==============================] - 31s 64ms/step - loss: 0.0190 - accuracy: 0.9931 - precision: 0.9934 - recall: 0.9923 - f1_score: 0.9925 - val_loss: 0.0161 - val_accuracy: 0.9948 - val_precision: 0.9910 - val_recall: 0.9984 - val_f1_score: 0.9942
# Epoch 30/70
# 478/478 [==============================] - 31s 64ms/step - loss: 0.0143 - accuracy: 0.9957 - precision: 0.9957 - recall: 0.9954 - f1_score: 0.9947 - val_loss: 0.0151 - val_accuracy: 0.9950 - val_precision: 0.9910 - val_recall: 0.9989 - val_f1_score: 0.9947
# Epoch 31/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0169 - accuracy: 0.9941 - precision: 0.9938 - recall: 0.9941 - f1_score: 0.9931 - val_loss: 0.0164 - val_accuracy: 0.9934 - val_precision: 0.9878 - val_recall: 0.9989 - val_f1_score: 0.9933
# Epoch 32/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0165 - accuracy: 0.9943 - precision: 0.9941 - recall: 0.9942 - f1_score: 0.9931 - val_loss: 0.0149 - val_accuracy: 0.9950 - val_precision: 0.9910 - val_recall: 0.9989 - val_f1_score: 0.9949
# Epoch 33/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0167 - accuracy: 0.9950 - precision: 0.9951 - recall: 0.9946 - f1_score: 0.9945 - val_loss: 0.0097 - val_accuracy: 0.9979 - val_precision: 0.9968 - val_recall: 0.9989 - val_f1_score: 0.9979
# Epoch 34/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0121 - accuracy: 0.9961 - precision: 0.9958 - recall: 0.9962 - f1_score: 0.9958 - val_loss: 0.0145 - val_accuracy: 0.9955 - val_precision: 0.9920 - val_recall: 0.9989 - val_f1_score: 0.9950
# Epoch 35/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0112 - accuracy: 0.9967 - precision: 0.9964 - recall: 0.9968 - f1_score: 0.9960 - val_loss: 0.0089 - val_accuracy: 0.9966 - val_precision: 0.9957 - val_recall: 0.9973 - val_f1_score: 0.9966
# Epoch 36/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0118 - accuracy: 0.9960 - precision: 0.9960 - recall: 0.9958 - f1_score: 0.9934 - val_loss: 0.0143 - val_accuracy: 0.9937 - val_precision: 0.9883 - val_recall: 0.9989 - val_f1_score: 0.9933
# Epoch 37/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0102 - accuracy: 0.9966 - precision: 0.9970 - recall: 0.9960 - f1_score: 0.9964 - val_loss: 0.0125 - val_accuracy: 0.9953 - val_precision: 0.9925 - val_recall: 0.9979 - val_f1_score: 0.9949
# Epoch 38/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0094 - accuracy: 0.9973 - precision: 0.9976 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.0156 - val_accuracy: 0.9950 - val_precision: 0.9910 - val_recall: 0.9989 - val_f1_score: 0.9948
# Epoch 39/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0082 - accuracy: 0.9971 - precision: 0.9969 - recall: 0.9970 - f1_score: 0.9969 - val_loss: 0.0058 - val_accuracy: 0.9984 - val_precision: 0.9979 - val_recall: 0.9989 - val_f1_score: 0.9983
# Epoch 40/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0119 - accuracy: 0.9959 - precision: 0.9958 - recall: 0.9957 - f1_score: 0.9948 - val_loss: 0.0063 - val_accuracy: 0.9984 - val_precision: 0.9984 - val_recall: 0.9984 - val_f1_score: 0.9986
# Epoch 41/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0096 - accuracy: 0.9971 - precision: 0.9976 - recall: 0.9965 - f1_score: 0.9970 - val_loss: 0.0078 - val_accuracy: 0.9966 - val_precision: 0.9936 - val_recall: 0.9995 - val_f1_score: 0.9967
# Epoch 42/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0090 - accuracy: 0.9963 - precision: 0.9964 - recall: 0.9961 - f1_score: 0.9963 - val_loss: 0.0199 - val_accuracy: 0.9937 - val_precision: 0.9873 - val_recall: 1.0000 - val_f1_score: 0.9931
# Epoch 43/70
# 478/478 [==============================] - 31s 64ms/step - loss: 0.0068 - accuracy: 0.9978 - precision: 0.9976 - recall: 0.9978 - f1_score: 0.9975 - val_loss: 0.0164 - val_accuracy: 0.9940 - val_precision: 0.9878 - val_recall: 1.0000 - val_f1_score: 0.9935
# Epoch 44/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0072 - accuracy: 0.9979 - precision: 0.9976 - recall: 0.9981 - f1_score: 0.9978 - val_loss: 0.0084 - val_accuracy: 0.9969 - val_precision: 0.9947 - val_recall: 0.9989 - val_f1_score: 0.9966
# Epoch 45/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0063 - accuracy: 0.9980 - precision: 0.9981 - recall: 0.9978 - f1_score: 0.9979 - val_loss: 0.0036 - val_accuracy: 0.9992 - val_precision: 0.9984 - val_recall: 1.0000 - val_f1_score: 0.9988
# Epoch 46/70
# 478/478 [==============================] - 31s 64ms/step - loss: 0.0086 - accuracy: 0.9971 - precision: 0.9969 - recall: 0.9972 - f1_score: 0.9967 - val_loss: 0.0069 - val_accuracy: 0.9976 - val_precision: 0.9957 - val_recall: 0.9995 - val_f1_score: 0.9974
# Epoch 47/70
# 478/478 [==============================] - 31s 64ms/step - loss: 0.0060 - accuracy: 0.9984 - precision: 0.9978 - recall: 0.9989 - f1_score: 0.9980 - val_loss: 0.0071 - val_accuracy: 0.9979 - val_precision: 0.9968 - val_recall: 0.9989 - val_f1_score: 0.9980
# Epoch 48/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0062 - accuracy: 0.9978 - precision: 0.9973 - recall: 0.9982 - f1_score: 0.9955 - val_loss: 0.0077 - val_accuracy: 0.9976 - val_precision: 0.9963 - val_recall: 0.9989 - val_f1_score: 0.9977
# Epoch 49/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0087 - accuracy: 0.9970 - precision: 0.9968 - recall: 0.9970 - f1_score: 0.9967 - val_loss: 0.0073 - val_accuracy: 0.9984 - val_precision: 0.9979 - val_recall: 0.9989 - val_f1_score: 0.9985
# Epoch 50/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0049 - accuracy: 0.9987 - precision: 0.9982 - recall: 0.9991 - f1_score: 0.9984 - val_loss: 0.0093 - val_accuracy: 0.9961 - val_precision: 0.9926 - val_recall: 0.9995 - val_f1_score: 0.9958
# Epoch 51/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0052 - accuracy: 0.9980 - precision: 0.9980 - recall: 0.9980 - f1_score: 0.9979 - val_loss: 0.0096 - val_accuracy: 0.9963 - val_precision: 0.9931 - val_recall: 0.9995 - val_f1_score: 0.9962
# Epoch 52/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0058 - accuracy: 0.9980 - precision: 0.9985 - recall: 0.9974 - f1_score: 0.9979 - val_loss: 0.0072 - val_accuracy: 0.9974 - val_precision: 0.9952 - val_recall: 0.9995 - val_f1_score: 0.9975
# Epoch 53/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0050 - accuracy: 0.9984 - precision: 0.9982 - recall: 0.9984 - f1_score: 0.9983 - val_loss: 0.0134 - val_accuracy: 0.9955 - val_precision: 0.9910 - val_recall: 1.0000 - val_f1_score: 0.9952
# Epoch 54/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0055 - accuracy: 0.9981 - precision: 0.9981 - recall: 0.9980 - f1_score: 0.9979 - val_loss: 0.0146 - val_accuracy: 0.9934 - val_precision: 0.9873 - val_recall: 0.9995 - val_f1_score: 0.9928
# Epoch 55/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0056 - accuracy: 0.9984 - precision: 0.9981 - recall: 0.9985 - f1_score: 0.9983 - val_loss: 0.0182 - val_accuracy: 0.9937 - val_precision: 0.9873 - val_recall: 1.0000 - val_f1_score: 0.9931
# Epoch 56/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0030 - accuracy: 0.9991 - precision: 0.9989 - recall: 0.9992 - f1_score: 0.9991 - val_loss: 0.0046 - val_accuracy: 0.9990 - val_precision: 0.9984 - val_recall: 0.9995 - val_f1_score: 0.9991
# Epoch 57/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0036 - accuracy: 0.9986 - precision: 0.9987 - recall: 0.9984 - f1_score: 0.9985 - val_loss: 0.0133 - val_accuracy: 0.9948 - val_precision: 0.9894 - val_recall: 1.0000 - val_f1_score: 0.9944
# Epoch 58/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0044 - accuracy: 0.9986 - precision: 0.9985 - recall: 0.9987 - f1_score: 0.9984 - val_loss: 0.0113 - val_accuracy: 0.9950 - val_precision: 0.9904 - val_recall: 0.9995 - val_f1_score: 0.9949
# Epoch 59/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0046 - accuracy: 0.9985 - precision: 0.9987 - recall: 0.9982 - f1_score: 0.9980 - val_loss: 0.0145 - val_accuracy: 0.9955 - val_precision: 0.9915 - val_recall: 0.9995 - val_f1_score: 0.9954
# Epoch 60/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0055 - accuracy: 0.9983 - precision: 0.9978 - recall: 0.9987 - f1_score: 0.9980 - val_loss: 0.0057 - val_accuracy: 0.9979 - val_precision: 0.9968 - val_recall: 0.9989 - val_f1_score: 0.9978
# Epoch 61/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0048 - accuracy: 0.9990 - precision: 0.9989 - recall: 0.9989 - f1_score: 0.9989 - val_loss: 0.0016 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000
# Epoch 62/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0038 - accuracy: 0.9991 - precision: 0.9993 - recall: 0.9989 - f1_score: 0.9992 - val_loss: 0.0027 - val_accuracy: 0.9992 - val_precision: 0.9984 - val_recall: 1.0000 - val_f1_score: 0.9993
# Epoch 63/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0040 - accuracy: 0.9992 - precision: 0.9992 - recall: 0.9992 - f1_score: 0.9992 - val_loss: 0.0022 - val_accuracy: 0.9995 - val_precision: 0.9989 - val_recall: 1.0000 - val_f1_score: 0.9995
# Epoch 64/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0027 - accuracy: 0.9992 - precision: 0.9992 - recall: 0.9992 - f1_score: 0.9992 - val_loss: 0.0041 - val_accuracy: 0.9984 - val_precision: 0.9968 - val_recall: 1.0000 - val_f1_score: 0.9982
# Epoch 65/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0048 - accuracy: 0.9982 - precision: 0.9978 - recall: 0.9985 - f1_score: 0.9977 - val_loss: 0.0039 - val_accuracy: 0.9987 - val_precision: 0.9979 - val_recall: 0.9995 - val_f1_score: 0.9987
# Epoch 66/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0021 - accuracy: 0.9995 - precision: 0.9993 - recall: 0.9997 - f1_score: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9995 - val_precision: 0.9989 - val_recall: 1.0000 - val_f1_score: 0.9995
# Epoch 67/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0032 - accuracy: 0.9987 - precision: 0.9984 - recall: 0.9989 - f1_score: 0.9987 - val_loss: 0.0036 - val_accuracy: 0.9992 - val_precision: 0.9995 - val_recall: 0.9989 - val_f1_score: 0.9993
# Epoch 68/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0020 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9995 - f1_score: 0.9995 - val_loss: 0.0032 - val_accuracy: 0.9990 - val_precision: 0.9979 - val_recall: 1.0000 - val_f1_score: 0.9991
# Epoch 69/70
# 478/478 [==============================] - 30s 63ms/step - loss: 0.0023 - accuracy: 0.9990 - precision: 0.9989 - recall: 0.9991 - f1_score: 0.9988 - val_loss: 0.0067 - val_accuracy: 0.9979 - val_precision: 0.9968 - val_recall: 0.9989 - val_f1_score: 0.9980
# Epoch 70/70
# 478/478 [==============================] - 30s 64ms/step - loss: 0.0028 - accuracy: 0.9991 - precision: 0.9992 - recall: 0.9991 - f1_score: 0.9990 - val_loss: 0.0043 - val_accuracy: 0.9987 - val_precision: 0.9979 - val_recall: 0.9995 - val_f1_score: 0.9986

# %%
import matplotlib.pyplot as plt

test_loss, test_acc, test_precision, test_recall, test_f1_score = model.evaluate(val_ds)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)
print('Test F1Score:', test_f1_score)

fig, axs = plt.subplots(5, figsize=(8, 12))

# Loss plot
axs[0].plot(history.history['loss'], label='train')
axs[0].plot(history.history['val_loss'], label='val')
axs[0].set_title('Model Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Accuracy plot
axs[1].plot(history.history['accuracy'], label='train')
axs[1].plot(history.history['val_accuracy'], label='val')
axs[1].set_title('Model Accuracy')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

# Precision plot
axs[2].plot(history.history['precision'], label='train')
axs[2].plot(history.history['val_precision'], label='val')
axs[2].set_title('Model Precision')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('Precision')
axs[2].legend()

# Recall plot
axs[3].plot(history.history['recall'], label='train')
axs[3].plot(history.history['val_recall'], label='val')
axs[3].set_title('Model Recall')
axs[3].set_xlabel('Epoch')
axs[3].set_ylabel('Recall')
axs[3].legend()

# F1Score plot
axs[4].plot(history.history['f1_score'], label='train')
axs[4].plot(history.history['val_f1_score'], label='val')
axs[4].set_title('Model F1Score')
axs[4].set_xlabel('Epoch')
axs[4].set_ylabel('F1Score')
axs[4].legend()

plt.tight_layout()
plt.show()
# Out:
# 120/120 [==============================] - 2s 14ms/step - loss: 0.0043 - accuracy: 0.9987 - precision: 0.9979 - recall: 0.9995 - f1_score: 0.9986
# Test Loss: 0.004291426856070757
# Test Accuracy: 0.9986897110939026
# Test Precision: 0.9978609681129456
# Test Recall: 0.9994643926620483
# Test F1Score: 0.9985665082931519

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

threshold = 0.999 # Limiar de decisão

y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = model.predict(val_ds)

y_true_binary = y_true.astype(int)
y_pred_binary = (y_pred > threshold).astype(int)

conf_matrix = confusion_matrix(y_true_binary, y_pred_binary)
class_report = classification_report(y_true_binary, y_pred_binary)

print('Confusion Matrix:', conf_matrix)
print('Classification Report:', class_report)
# Out:
# 120/120 [==============================] - 2s 12ms/step
# Confusion Matrix: [[1949    0]
#  [ 128 1739]]
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1949
#            1       1.00      0.93      0.96      1867
#
#     accuracy                           0.97      3816
#    macro avg       0.97      0.97      0.97      3816
# weighted avg       0.97      0.97      0.97      3816
